# %% [markdown]
# # UI
#
# Let's start with some toying

# %% [markdown]
# $$ \int_{\Omega}{dP} = 1 $$
#
# \begin{align}
# \int_{\Omega}{dP} &= P(\Omega) \\
# &= 1
# \end{align}

# %% [markdown]
# ## Pandas

# %% [markdown]
# _Sorry for this data set. I hope this does not make anybody uncomfortable, just could not think of a high attribute data set_.

# %%
from sklearn.datasets import load_breast_cancer
import pandas as pd

# %%
bc = load_breast_cancer()

# %%
df = pd.DataFrame(data=bc.data, index=bc.target, columns=bc.feature_names)
df
# Out:
#     mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0        17.990         10.38          122.80     1001.0          0.11840
# 0        20.570         17.77          132.90     1326.0          0.08474
# 0        19.690         21.25          130.00     1203.0          0.10960
# 0        11.420         20.38           77.58      386.1          0.14250
# 0        20.290         14.34          135.10     1297.0          0.10030
# 0        12.450         15.70           82.57      477.1          0.12780
# 0        18.250         19.98          119.60     1040.0          0.09463
# 0        13.710         20.83           90.20      577.9          0.11890
# 0        13.000         21.82           87.50      519.8          0.12730
# 0        12.460         24.04           83.97      475.9          0.11860
# 0        16.020         23.24          102.70      797.8          0.08206
# 0        15.780         17.89          103.60      781.0          0.09710
# ...

# %% [markdown]
# Notice the "..."

# %%
# %load snippets/pandas_settings.py
import pandas as pd

# Set Pandas display options for easier reading
pd.set_option("max_colwidth", 100)
pd.set_option("display.max_rows", 1000)
pd.set_option("display.max_columns", 9001)  # there is a scrollbar and '...' just looks stupid
pd.set_option('display.float_format', lambda x: '{:,.2f}'.format(x))

# %%
df
# Out:
#    mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0        17.99         10.38          122.80   1,001.00             0.12
# 0        20.57         17.77          132.90   1,326.00             0.08
# 0        19.69         21.25          130.00   1,203.00             0.11
# 0        11.42         20.38           77.58     386.10             0.14
# 0        20.29         14.34          135.10   1,297.00             0.10
# 0        12.45         15.70           82.57     477.10             0.13
# 0        18.25         19.98          119.60   1,040.00             0.09
# 0        13.71         20.83           90.20     577.90             0.12
# 0        13.00         21.82           87.50     519.80             0.13
# 0        12.46         24.04           83.97     475.90             0.12
# 0        16.02         23.24          102.70     797.80             0.08
# 0        15.78         17.89          103.60     781.00             0.10
# ...

# %%
from IPython.display import display, HTML

css = """
    .blink {
        animation-duration: 1s;
        animation-name: blink;
        animation-iteration-count: infinite;
        animation-timing-function: steps(2, start);
    }
    @keyframes blink {
        80% {
            visibility: hidden;
        }
    }"""

to_show = HTML(
    '<style>{}</style>'.format(css) +
    '<p class="blink"> Jupyter IS AWESOME!!!!! </p>'
)

display(to_show)
# Out:
# <style>
#     .blink {
#         animation-duration: 1s;
#         animation-name: blink;
#         animation-iteration-count: infinite;
#         animation-timing-function: steps(2, start);
#     }
#     @keyframes blink {
#         80% {
#             visibility: hidden;
#         }
#     }</style><p class="blink"> Jupyter IS AWESOME!!!!! </p>

# %% [markdown]
# ## Extensions

# %% [markdown]
# Have to get back installing them first, then start to work with them.
